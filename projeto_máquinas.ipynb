# %% [markdown]
#    # Trabalho de Projetos de Máquinas
#
#    ### - Universidade Federal do Rio de Janeiro - Macaé
#
#    #### - Título: Técnicas de Aprendizado de Máquina na Engenharia Mecânica
#
#    #### - Autor: Pietro Sales
#
#    ##### - Referências:
#
#    [1].	Li Y, Yang Y, Li G, Xu M, Huang W. A fault diagnosis scheme for planetary gearboxes using modified multi-scale symbolic dynamic entropy and mRMR feature selection. Mech Syst Signal Process. 2017; 91: 295±312. https://doi.org/10.1016/j.ymssp.2016.12.040
#
# [2].	Case Western Reserve University Bearing Data Centre website. Disponível em: <http://csegroups.case.edu/bearingdatacenter>. Acesso em: 16 jul. 2018.
#
#
# [3].	Hui, Kar Hoou; Ooi, Ching Sheng; Lim, Meng Hee; Leong, Mohd Salman; Al-Obaidi, Salah Mahdi. PLoS ONE. 12/20/2017, Vol. 12 Issue 12, p1-10. 10p. DOI: 10.1371/journal.pone.0189143
#
#
# [4].	Simplifying Logistic Regression. DZONE. Disponível em: <https://dzone.com/articles/machinex-simplifying-logistic-regression>. Acesso em: 16 jul. 2018.
#
#
# [5].	Logistic Regression. ML CHEATSHEET. Disponível em: <http://ml-cheatsheet.readthedocs.io/en/latest/logistic_regression.html#gradient-descent>. Acesso em: 16 jul. 2018.
#
#    #### - Fonte dos dados:
# Experimento e dados crus obtidos por [2].
#
# Dados utilizados no treino dos modelos foram tratados por [1].

# %% [markdown]
# # Algoritmo

# %% [markdown]
# ## Passo preliminar: Visualização dos dados de vibração obtidos por [2]

# %%
raw_normal_data = pd.read_csv("X097_DE_time.csv", header=None)

x = np.arange(0,243938)

plt.scatter(x,raw_normal_data)
plt.xlim(1000, 1100)
plt.xlabel("Tempo")
plt.ylabel("Deslocamento")
plt.title("Deslocamento X Tempo")
plt.savefig('fig1.png', dpi = 300)
plt.show()

# %% [markdown]
# # 1) Importar bibliotecas

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import Adam

from sklearn.linear_model import LogisticRegression
from sklearn import metrics

import pandas as pd

# %matplotlib inline
import matplotlib.pyplot as plt

import numpy as np

# %% [markdown]
# # 2) Ler e visualizar os dados

# %%
training_data = pd.read_csv("training.csv")
testing_data = pd.read_csv('testing.csv')
labels_data = pd.read_csv('target.csv')

training_data.head(10)
# Out:
#    skewness factor  kurtosis factor  crest factor  shape factor  \
# 0        -0.301250         2.481710      2.775495      1.194182
# 1        -0.192214         2.531206      2.426969      1.206328
# 2        -0.175213         2.559090      2.492546      1.215273
# 3        -0.029234         2.316718      2.469554      1.209672
# 4         0.022078         2.708726      2.815036      1.247238
# 5        -0.211558         2.755039      2.957466      1.226729
# 6         0.140896         2.794350      2.661178      1.267598
# 7        -0.316860         2.615248      2.822367      1.220262
# 8        -0.044224         2.482811      2.793800      1.218165
# 9        -0.242878         2.682910      2.700426      1.217775
#
#    impulse factor  margin factor
# 0        3.314447       3.826980
# 1        2.927721       3.361278
# 2        3.029125       3.503304
# 3        2.987349       3.467161
# 4        3.511020       4.138479
# 5        3.628010       4.241124
# 6        3.373305       4.018224
# 7        3.444027       4.034513
# 8        3.403310       3.934936
# 9        3.288513       3.812402

# %%
skewness_factor = training_data['skewness factor']
shape_factor = training_data['shape factor']

x_0 = skewness_factor[0:50]
y_0 = shape_factor[0:50]

x_1 = skewness_factor[50:100]
y_1 = shape_factor[50:100]

x_2 = skewness_factor[100:150]
y_2 = shape_factor[100:150]

x_3 = skewness_factor[150:200]
y_3 = shape_factor[150:200]

plt.scatter(x_0,y_0, c='r', label = 'Saudável')
plt.scatter(x_1,y_1, c='b', label = 'Falha Esferas')
plt.scatter(x_2,y_2, c='y', label = 'Falha Interna')
plt.scatter(x_3,y_3, c='g', label = 'Falha Externa')
plt.xlabel("Fator de Assimetria")
plt.ylabel("Fator de Forma")
plt.legend()
plt.savefig('fig2.png', dpi = 300)
plt.show()

# %% [markdown]
# # 3) Regressão Logística

# %% [markdown]
# ## 3.1) Treinando o modelo utilizando Fator de Forma e Assimetria

# %%
X_train = training_data[['skewness factor','kurtosis factor']].values
X_test = testing_data[['skewness factor','kurtosis factor']].values
y_train = labels_data.values
y_test = labels_data.values

y_train = np.argmax(y_train, axis=1)
y_test = np.argmax(y_test, axis=1)

logreg = LogisticRegression()
logreg.fit(X_train, y_train)

y_pred = logreg.predict(X_test)
print('Precisão: {:.2f}'.format(logreg.score(X_test, y_test)))
# Out:
# Precisão: 0.81

# %% [markdown]
# ## 3.2) Curva de decisão utlizando Fator de Forma e Assimetria

# %%
X = X_train
y = y_train
# Plot the decision boundary. For that, we will assign a color to each
# point in the mesh [x_min, x_max]x[y_min, y_max].
h = 0.02
x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
Z = logreg.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.figure(1, figsize=(8, 6))
plt.pcolormesh(xx, yy, Z, cmap=plt.cm.Paired)

# Plot also the training points
plt.scatter(X[:, 0], X[:, 1], c=y, edgecolors='k', cmap=plt.cm.Paired)
plt.xlabel('Fator de Forma')
plt.ylabel('Fator de Assimetria')
plt.title("Curva de Decisão")
plt.savefig('fig3.png', dpi=300)

plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())

plt.show()

# %% [markdown]
# ## 3.3) Treinando o modelo utilizando todos parâmetros

# %%
X_train = training_data.values
X_test = testing_data.values
y_train = labels_data.values
y_test = labels_data.values

y_train = np.argmax(y_train, axis=1)
y_test = np.argmax(y_test, axis=1)

logreg = LogisticRegression()
logreg.fit(X_train, y_train)

y_pred = logreg.predict(X_test)
print('\nPrecisão da regressão logística: {:.2f}'.format(logreg.score(X_test, y_test)))
# Out:
# Precisão da regressão logística: 0.83

# %% [markdown]
# # 4) Rede Neural

# %%
model = Sequential()
model.add(Dense(100, activation='sigmoid', input_shape=(6,)))
model.add(Dense(50, activation='sigmoid'))
model.add(Dense(25, activation='sigmoid'))
model.add(Dense(4, activation='sigmoid'))

model.compile(loss='categorical_crossentropy',
             optimizer=Adam(),
             metrics=['accuracy'])

history = model.fit(X_train, labels_data.values,
                    batch_size=1,
                    epochs=200,
                    verbose=2,
                   validation_data=(X_test, labels_data.values))
# Out:
# Train on 200 samples, validate on 200 samples
# Epoch 1/200
#  - 1s - loss: 1.4186 - acc: 0.2300 - val_loss: 1.3810 - val_acc: 0.2500
# Epoch 2/200
#  - 0s - loss: 1.3757 - acc: 0.2400 - val_loss: 1.3406 - val_acc: 0.2500
# Epoch 3/200
#  - 0s - loss: 1.2998 - acc: 0.3750 - val_loss: 1.1970 - val_acc: 0.5150
# Epoch 4/200
#  - 0s - loss: 1.0897 - acc: 0.5050 - val_loss: 0.9723 - val_acc: 0.4900
# Epoch 5/200
#  - 0s - loss: 0.8997 - acc: 0.5350 - val_loss: 0.8275 - val_acc: 0.5400
# Epoch 6/200
#  - 0s - loss: 0.7973 - acc: 0.5600 - val_loss: 0.7638 - val_acc: 0.5900
# Epoch 7/200
#  - 0s - loss: 0.7556 - acc: 0.6300 - val_loss: 0.7278 - val_acc: 0.6650
# Epoch 8/200
#  - 0s - loss: 0.7235 - acc: 0.6600 - val_loss: 0.6956 - val_acc: 0.7050
# Epoch 9/200
#  - 0s - loss: 0.6897 - acc: 0.7350 - val_loss: 0.6645 - val_acc: 0.7500
# Epoch 10/200
#  - 0s - loss: 0.6569 - acc: 0.7100 - val_loss: 0.6350 - val_acc: 0.7500
# Epoch 11/200
#  - 0s - loss: 0.6243 - acc: 0.7550 - val_loss: 0.6344 - val_acc: 0.7800
# Epoch 12/200
#  - 0s - loss: 0.5985 - acc: 0.7550 - val_loss: 0.5653 - val_acc: 0.8050
# Epoch 13/200
#  - 0s - loss: 0.5368 - acc: 0.8050 - val_loss: 0.5405 - val_acc: 0.7400
# Epoch 14/200
#  - 0s - loss: 0.5320 - acc: 0.7250 - val_loss: 0.5347 - val_acc: 0.7700
# Epoch 15/200
#  - 0s - loss: 0.4940 - acc: 0.8100 - val_loss: 0.4782 - val_acc: 0.8200
# Epoch 16/200
#  - 0s - loss: 0.4640 - acc: 0.8200 - val_loss: 0.4885 - val_acc: 0.7800
# Epoch 17/200
#  - 0s - loss: 0.4355 - acc: 0.8250 - val_loss: 0.4582 - val_acc: 0.7900
# Epoch 18/200
#  - 0s - loss: 0.4461 - acc: 0.7950 - val_loss: 0.4257 - val_acc: 0.8250
# Epoch 19/200
#  - 0s - loss: 0.3945 - acc: 0.8550 - val_loss: 0.3989 - val_acc: 0.8500
# Epoch 20/200
#  - 0s - loss: 0.3914 - acc: 0.8250 - val_loss: 0.4076 - val_acc: 0.8450
# Epoch 21/200
#  - 0s - loss: 0.3715 - acc: 0.8500 - val_loss: 0.3838 - val_acc: 0.8250
# Epoch 22/200
#  - 0s - loss: 0.3636 - acc: 0.8350 - val_loss: 0.5256 - val_acc: 0.7750
# Epoch 23/200
#  - 0s - loss: 0.3779 - acc: 0.8350 - val_loss: 0.3770 - val_acc: 0.8500
# Epoch 24/200
#  - 0s - loss: 0.3225 - acc: 0.8850 - val_loss: 0.3581 - val_acc: 0.8450
# Epoch 25/200
#  - 0s - loss: 0.3257 - acc: 0.8700 - val_loss: 0.3542 - val_acc: 0.8450
# Epoch 26/200
#  - 0s - loss: 0.3260 - acc: 0.8700 - val_loss: 0.3364 - val_acc: 0.8600
# Epoch 27/200
#  - 0s - loss: 0.3127 - acc: 0.8800 - val_loss: 0.3550 - val_acc: 0.8150
# Epoch 28/200
#  - 0s - loss: 0.3124 - acc: 0.8500 - val_loss: 0.3199 - val_acc: 0.8450
# Epoch 29/200
#  - 0s - loss: 0.3160 - acc: 0.8700 - val_loss: 0.3364 - val_acc: 0.8400
# Epoch 30/200
#  - 0s - loss: 0.2965 - acc: 0.8650 - val_loss: 0.3769 - val_acc: 0.8100
# Epoch 31/200
#  - 0s - loss: 0.3106 - acc: 0.8500 - val_loss: 0.3040 - val_acc: 0.8650
# Epoch 32/200
#  - 0s - loss: 0.2941 - acc: 0.8550 - val_loss: 0.2956 - val_acc: 0.8600
# Epoch 33/200
#  - 0s - loss: 0.2667 - acc: 0.8750 - val_loss: 0.3048 - val_acc: 0.8650
# Epoch 34/200
#  - 0s - loss: 0.2662 - acc: 0.8950 - val_loss: 0.3035 - val_acc: 0.8750
# Epoch 35/200
#  - 0s - loss: 0.2642 - acc: 0.8850 - val_loss: 0.3028 - val_acc: 0.8650
# Epoch 36/200
#  - 0s - loss: 0.2578 - acc: 0.9050 - val_loss: 0.2833 - val_acc: 0.8600
# Epoch 37/200
#  - 0s - loss: 0.2516 - acc: 0.9000 - val_loss: 0.3140 - val_acc: 0.8650
# Epoch 38/200
#  - 0s - loss: 0.2498 - acc: 0.9000 - val_loss: 0.3022 - val_acc: 0.8500
# Epoch 39/200
#  - 0s - loss: 0.2693 - acc: 0.8700 - val_loss: 0.2952 - val_acc: 0.8550
# Epoch 40/200
#  - 0s - loss: 0.2555 - acc: 0.8900 - val_loss: 0.3028 - val_acc: 0.8550
# Epoch 41/200
#  - 0s - loss: 0.2402 - acc: 0.8900 - val_loss: 0.2757 - val_acc: 0.8650
# Epoch 42/200
#  - 0s - loss: 0.2477 - acc: 0.8850 - val_loss: 0.2645 - val_acc: 0.8800
# Epoch 43/200
#  - 0s - loss: 0.2409 - acc: 0.8900 - val_loss: 0.2982 - val_acc: 0.8700
# Epoch 44/200
#  - 0s - loss: 0.2390 - acc: 0.9000 - val_loss: 0.2674 - val_acc: 0.8750
# Epoch 45/200
#  - 0s - loss: 0.2314 - acc: 0.8900 - val_loss: 0.2619 - val_acc: 0.8750
# Epoch 46/200
#  - 0s - loss: 0.2283 - acc: 0.9100 - val_loss: 0.2748 - val_acc: 0.8800
# Epoch 47/200
#  - 0s - loss: 0.2366 - acc: 0.8900 - val_loss: 0.2805 - val_acc: 0.8750
# Epoch 48/200
#  - 0s - loss: 0.2806 - acc: 0.8750 - val_loss: 0.2638 - val_acc: 0.8700
# Epoch 49/200
#  - 0s - loss: 0.2354 - acc: 0.8950 - val_loss: 0.2575 - val_acc: 0.8700
# Epoch 50/200
#  - 0s - loss: 0.2403 - acc: 0.8900 - val_loss: 0.2830 - val_acc: 0.8750
# Epoch 51/200
#  - 0s - loss: 0.2197 - acc: 0.9100 - val_loss: 0.2654 - val_acc: 0.8850
# Epoch 52/200
#  - 0s - loss: 0.2310 - acc: 0.8900 - val_loss: 0.2511 - val_acc: 0.8850
# Epoch 53/200
#  - 0s - loss: 0.2282 - acc: 0.8950 - val_loss: 0.2596 - val_acc: 0.8800
# Epoch 54/200
#  - 0s - loss: 0.2262 - acc: 0.9100 - val_loss: 0.2624 - val_acc: 0.8800
# Epoch 55/200
#  - 0s - loss: 0.2202 - acc: 0.9000 - val_loss: 0.2509 - val_acc: 0.8800
# Epoch 56/200
#  - 0s - loss: 0.2226 - acc: 0.9000 - val_loss: 0.2539 - val_acc: 0.8750
# Epoch 57/200
#  - 0s - loss: 0.2647 - acc: 0.8700 - val_loss: 0.2579 - val_acc: 0.8850
# Epoch 58/200
#  - 0s - loss: 0.2163 - acc: 0.9000 - val_loss: 0.2449 - val_acc: 0.8700
# Epoch 59/200
#  - 0s - loss: 0.2215 - acc: 0.8900 - val_loss: 0.2404 - val_acc: 0.8900
# Epoch 60/200
#  - 0s - loss: 0.2219 - acc: 0.8900 - val_loss: 0.2541 - val_acc: 0.8850
# Epoch 61/200
#  - 0s - loss: 0.2172 - acc: 0.8950 - val_loss: 0.2697 - val_acc: 0.8700
# Epoch 62/200
#  - 0s - loss: 0.2263 - acc: 0.9000 - val_loss: 0.2676 - val_acc: 0.8800
# Epoch 63/200
#  - 0s - loss: 0.2174 - acc: 0.9000 - val_loss: 0.2399 - val_acc: 0.8850
# Epoch 64/200
#  - 0s - loss: 0.2170 - acc: 0.9000 - val_loss: 0.2433 - val_acc: 0.8900
# Epoch 65/200
#  - 0s - loss: 0.2248 - acc: 0.8850 - val_loss: 0.2397 - val_acc: 0.8850
# Epoch 66/200
#  - 0s - loss: 0.2141 - acc: 0.9000 - val_loss: 0.2627 - val_acc: 0.8750
# Epoch 67/200
#  - 0s - loss: 0.2264 - acc: 0.8850 - val_loss: 0.5930 - val_acc: 0.7800
# Epoch 68/200
#  - 0s - loss: 0.2375 - acc: 0.8950 - val_loss: 0.2397 - val_acc: 0.8950
# Epoch 69/200
#  - 0s - loss: 0.2128 - acc: 0.8950 - val_loss: 0.2348 - val_acc: 0.8900
# Epoch 70/200
#  - 0s - loss: 0.2156 - acc: 0.8950 - val_loss: 0.2398 - val_acc: 0.8750
# Epoch 71/200
#  - 0s - loss: 0.2185 - acc: 0.9000 - val_loss: 0.2297 - val_acc: 0.8950
# Epoch 72/200
#  - 0s - loss: 0.2106 - acc: 0.9000 - val_loss: 0.2528 - val_acc: 0.8750
# Epoch 73/200
#  - 0s - loss: 0.2113 - acc: 0.9000 - val_loss: 0.2317 - val_acc: 0.8850
# Epoch 74/200
#  - 0s - loss: 0.2062 - acc: 0.9050 - val_loss: 0.2436 - val_acc: 0.8900
# Epoch 75/200
#  - 0s - loss: 0.3160 - acc: 0.8800 - val_loss: 0.2943 - val_acc: 0.8600
# Epoch 76/200
#  - 0s - loss: 0.2107 - acc: 0.9050 - val_loss: 0.2419 - val_acc: 0.8900
# Epoch 77/200
#  - 0s - loss: 0.2116 - acc: 0.9050 - val_loss: 0.2444 - val_acc: 0.8850
# Epoch 78/200
#  - 0s - loss: 0.2103 - acc: 0.8950 - val_loss: 0.2357 - val_acc: 0.8800
# Epoch 79/200
#  - 0s - loss: 0.2114 - acc: 0.8900 - val_loss: 0.2404 - val_acc: 0.8900
# Epoch 80/200
#  - 0s - loss: 0.2148 - acc: 0.9050 - val_loss: 0.2409 - val_acc: 0.8800
# Epoch 81/200
#  - 0s - loss: 0.2133 - acc: 0.8950 - val_loss: 0.2438 - val_acc: 0.8850
# Epoch 82/200
#  - 0s - loss: 0.2094 - acc: 0.9000 - val_loss: 0.2729 - val_acc: 0.8650
# Epoch 83/200
#  - 0s - loss: 0.2305 - acc: 0.8950 - val_loss: 0.2454 - val_acc: 0.8850
# Epoch 84/200
#  - 0s - loss: 0.2170 - acc: 0.9100 - val_loss: 0.2405 - val_acc: 0.8850
# Epoch 85/200
#  - 0s - loss: 0.2111 - acc: 0.9050 - val_loss: 0.2636 - val_acc: 0.8750
# Epoch 86/200
#  - 0s - loss: 0.2105 - acc: 0.9000 - val_loss: 0.2546 - val_acc: 0.8850
# Epoch 87/200
#  - 0s - loss: 0.2113 - acc: 0.9050 - val_loss: 0.2277 - val_acc: 0.9000
# Epoch 88/200
#  - 0s - loss: 0.2104 - acc: 0.9050 - val_loss: 0.2307 - val_acc: 0.8950
# Epoch 89/200
#  - 0s - loss: 0.2127 - acc: 0.8850 - val_loss: 0.2342 - val_acc: 0.8950
# Epoch 90/200
#  - 0s - loss: 0.2179 - acc: 0.8950 - val_loss: 0.2255 - val_acc: 0.9000
# Epoch 91/200
#  - 0s - loss: 0.2092 - acc: 0.9000 - val_loss: 0.2396 - val_acc: 0.8700
# Epoch 92/200
#  - 0s - loss: 0.4218 - acc: 0.8200 - val_loss: 0.4791 - val_acc: 0.7900
# Epoch 93/200
#  - 0s - loss: 0.2242 - acc: 0.9000 - val_loss: 0.2336 - val_acc: 0.8850
# Epoch 94/200
#  - 0s - loss: 0.2070 - acc: 0.9100 - val_loss: 0.2253 - val_acc: 0.8950
# Epoch 95/200
#  - 0s - loss: 0.2043 - acc: 0.9050 - val_loss: 0.2268 - val_acc: 0.8900
# Epoch 96/200
#  - 0s - loss: 0.2051 - acc: 0.9050 - val_loss: 0.2366 - val_acc: 0.8750
# Epoch 97/200
#  - 0s - loss: 0.2162 - acc: 0.8850 - val_loss: 0.2297 - val_acc: 0.9000
# Epoch 98/200
#  - 0s - loss: 0.2077 - acc: 0.8950 - val_loss: 0.2288 - val_acc: 0.8900
# Epoch 99/200
#  - 0s - loss: 0.2085 - acc: 0.9050 - val_loss: 0.2271 - val_acc: 0.8950
# Epoch 100/200
#  - 0s - loss: 0.2062 - acc: 0.8950 - val_loss: 0.2331 - val_acc: 0.8850
# Epoch 101/200
#  - 0s - loss: 0.2027 - acc: 0.9050 - val_loss: 0.2268 - val_acc: 0.8900
# Epoch 102/200
#  - 0s - loss: 0.2079 - acc: 0.9000 - val_loss: 0.2276 - val_acc: 0.9000
# Epoch 103/200
#  - 0s - loss: 0.2098 - acc: 0.8950 - val_loss: 0.2464 - val_acc: 0.8900
# Epoch 104/200
#  - 0s - loss: 0.2128 - acc: 0.9050 - val_loss: 0.2278 - val_acc: 0.9000
# Epoch 105/200
#  - 0s - loss: 0.2053 - acc: 0.9050 - val_loss: 0.2568 - val_acc: 0.8750
# Epoch 106/200
#  - 0s - loss: 0.2081 - acc: 0.9000 - val_loss: 0.2221 - val_acc: 0.8950
# Epoch 107/200
#  - 0s - loss: 0.2139 - acc: 0.9000 - val_loss: 0.2304 - val_acc: 0.9000
# Epoch 108/200
#  - 0s - loss: 0.2030 - acc: 0.9050 - val_loss: 0.2412 - val_acc: 0.8900
# Epoch 109/200
#  - 0s - loss: 0.2108 - acc: 0.9000 - val_loss: 0.2382 - val_acc: 0.8900
# Epoch 110/200
#  - 0s - loss: 0.3108 - acc: 0.8550 - val_loss: 0.3117 - val_acc: 0.8750
# Epoch 111/200
#  - 0s - loss: 0.2175 - acc: 0.8850 - val_loss: 0.2950 - val_acc: 0.8650
# Epoch 112/200
#  - 0s - loss: 0.2042 - acc: 0.9200 - val_loss: 0.2948 - val_acc: 0.8450
# Epoch 113/200
#  - 0s - loss: 0.2189 - acc: 0.9050 - val_loss: 0.2292 - val_acc: 0.9000
# Epoch 114/200
#  - 0s - loss: 0.2021 - acc: 0.9000 - val_loss: 0.2402 - val_acc: 0.8950
# Epoch 115/200
#  - 0s - loss: 0.2072 - acc: 0.9050 - val_loss: 0.2395 - val_acc: 0.8700
# Epoch 116/200
#  - 0s - loss: 0.2047 - acc: 0.9000 - val_loss: 0.2288 - val_acc: 0.9000
# Epoch 117/200
#  - 0s - loss: 0.2046 - acc: 0.9050 - val_loss: 0.2458 - val_acc: 0.8650
# Epoch 118/200
#  - 0s - loss: 0.2051 - acc: 0.8950 - val_loss: 0.2386 - val_acc: 0.8950
# Epoch 119/200
#  - 0s - loss: 0.2067 - acc: 0.9050 - val_loss: 0.2233 - val_acc: 0.9000
# Epoch 120/200
#  - 0s - loss: 0.2107 - acc: 0.9000 - val_loss: 0.2212 - val_acc: 0.9000
# Epoch 121/200
#  - 0s - loss: 0.2132 - acc: 0.8850 - val_loss: 0.2240 - val_acc: 0.9000
# Epoch 122/200
#  - 0s - loss: 0.2030 - acc: 0.9100 - val_loss: 0.2251 - val_acc: 0.8900
# Epoch 123/200
#  - 0s - loss: 0.2048 - acc: 0.9050 - val_loss: 0.2305 - val_acc: 0.8700
# Epoch 124/200
#  - 0s - loss: 0.2080 - acc: 0.9000 - val_loss: 0.2550 - val_acc: 0.8900
# Epoch 125/200
#  - 0s - loss: 0.2097 - acc: 0.8950 - val_loss: 0.2374 - val_acc: 0.8950
# Epoch 126/200
#  - 0s - loss: 0.2132 - acc: 0.8950 - val_loss: 0.2600 - val_acc: 0.8700
# Epoch 127/200
#  - 0s - loss: 0.3220 - acc: 0.8600 - val_loss: 0.2863 - val_acc: 0.8600
# Epoch 128/200
#  - 0s - loss: 0.2509 - acc: 0.8900 - val_loss: 0.2508 - val_acc: 0.8900
# Epoch 129/200
#  - 0s - loss: 0.2026 - acc: 0.9100 - val_loss: 0.2224 - val_acc: 0.8950
# Epoch 130/200
#  - 0s - loss: 0.2085 - acc: 0.9000 - val_loss: 0.2241 - val_acc: 0.9000
# Epoch 131/200
#  - 0s - loss: 0.2046 - acc: 0.9050 - val_loss: 0.2247 - val_acc: 0.9000
# Epoch 132/200
#  - 0s - loss: 0.2018 - acc: 0.9000 - val_loss: 0.2362 - val_acc: 0.8950
# Epoch 133/200
#  - 0s - loss: 0.2078 - acc: 0.9000 - val_loss: 0.2235 - val_acc: 0.9000
# Epoch 134/200
#  - 0s - loss: 0.2040 - acc: 0.9050 - val_loss: 0.2658 - val_acc: 0.8650
# Epoch 135/200
#  - 0s - loss: 0.2091 - acc: 0.9050 - val_loss: 0.2360 - val_acc: 0.8950
# Epoch 136/200
#  - 0s - loss: 0.2073 - acc: 0.8950 - val_loss: 0.2521 - val_acc: 0.8850
# Epoch 137/200
#  - 0s - loss: 0.2656 - acc: 0.8750 - val_loss: 0.2405 - val_acc: 0.8900
# Epoch 138/200
#  - 0s - loss: 0.2029 - acc: 0.9000 - val_loss: 0.2235 - val_acc: 0.8950
# Epoch 139/200
#  - 0s - loss: 0.2025 - acc: 0.9050 - val_loss: 0.2294 - val_acc: 0.8800
# Epoch 140/200
#  - 0s - loss: 0.1937 - acc: 0.9200 - val_loss: 0.3039 - val_acc: 0.8550
# Epoch 141/200
#  - 0s - loss: 0.2197 - acc: 0.8950 - val_loss: 0.2479 - val_acc: 0.8900
# Epoch 142/200
#  - 0s - loss: 0.2033 - acc: 0.9000 - val_loss: 0.2449 - val_acc: 0.8900
# Epoch 143/200
#  - 0s - loss: 0.2051 - acc: 0.8900 - val_loss: 0.2341 - val_acc: 0.8950
# Epoch 144/200
#  - 0s - loss: 0.2107 - acc: 0.9000 - val_loss: 0.2279 - val_acc: 0.9000
# Epoch 145/200
#  - 0s - loss: 0.2047 - acc: 0.9050 - val_loss: 0.2227 - val_acc: 0.8950
# Epoch 146/200
#  - 0s - loss: 0.2135 - acc: 0.8950 - val_loss: 0.2262 - val_acc: 0.8950
# Epoch 147/200
#  - 0s - loss: 0.2162 - acc: 0.8950 - val_loss: 0.2259 - val_acc: 0.9000
# Epoch 148/200
#  - 0s - loss: 0.2029 - acc: 0.9200 - val_loss: 0.2219 - val_acc: 0.8950
# Epoch 149/200
#  - 0s - loss: 0.2026 - acc: 0.9050 - val_loss: 0.2449 - val_acc: 0.8850
# Epoch 150/200
#  - 0s - loss: 0.2045 - acc: 0.9000 - val_loss: 0.2282 - val_acc: 0.9000
# Epoch 151/200
#  - 0s - loss: 0.2056 - acc: 0.9000 - val_loss: 0.2226 - val_acc: 0.9000
# Epoch 152/200
#  - 0s - loss: 0.2063 - acc: 0.9050 - val_loss: 0.2253 - val_acc: 0.8950
# Epoch 153/200
#  - 0s - loss: 0.2057 - acc: 0.8950 - val_loss: 0.2479 - val_acc: 0.8650
# Epoch 154/200
#  - 0s - loss: 0.2360 - acc: 0.8950 - val_loss: 0.3054 - val_acc: 0.8900
# Epoch 155/200
#  - 0s - loss: 0.2110 - acc: 0.9000 - val_loss: 0.2277 - val_acc: 0.8900
# Epoch 156/200
#  - 0s - loss: 0.2062 - acc: 0.9050 - val_loss: 0.2275 - val_acc: 0.9000
# Epoch 157/200
#  - 0s - loss: 0.2032 - acc: 0.9000 - val_loss: 0.2217 - val_acc: 0.8950
# Epoch 158/200
#  - 0s - loss: 0.2058 - acc: 0.8950 - val_loss: 0.2310 - val_acc: 0.9000
# Epoch 159/200
#  - 0s - loss: 0.2043 - acc: 0.9000 - val_loss: 0.2184 - val_acc: 0.8900
# Epoch 160/200
#  - 0s - loss: 0.2056 - acc: 0.8900 - val_loss: 0.2335 - val_acc: 0.9000
# Epoch 161/200
#  - 0s - loss: 0.2044 - acc: 0.9000 - val_loss: 0.2232 - val_acc: 0.9000
# Epoch 162/200
#  - 0s - loss: 0.2021 - acc: 0.9100 - val_loss: 0.2439 - val_acc: 0.8650
# Epoch 163/200
#  - 0s - loss: 0.2374 - acc: 0.8650 - val_loss: 0.2305 - val_acc: 0.8950
# Epoch 164/200
#  - 0s - loss: 0.2052 - acc: 0.9050 - val_loss: 0.2281 - val_acc: 0.9000
# Epoch 165/200
#  - 0s - loss: 0.2039 - acc: 0.9100 - val_loss: 0.2213 - val_acc: 0.8900
# Epoch 166/200
#  - 0s - loss: 0.2017 - acc: 0.9050 - val_loss: 0.2238 - val_acc: 0.9000
# Epoch 167/200
#  - 0s - loss: 0.2011 - acc: 0.9050 - val_loss: 0.2315 - val_acc: 0.8900
# Epoch 168/200
#  - 0s - loss: 0.2156 - acc: 0.9050 - val_loss: 0.2249 - val_acc: 0.9000
# Epoch 169/200
#  - 0s - loss: 0.2039 - acc: 0.9050 - val_loss: 0.2242 - val_acc: 0.8950
# Epoch 170/200
#  - 0s - loss: 0.2022 - acc: 0.8900 - val_loss: 0.2280 - val_acc: 0.8900
# Epoch 171/200
#  - 0s - loss: 0.2710 - acc: 0.8800 - val_loss: 0.2252 - val_acc: 0.8900
# Epoch 172/200
#  - 0s - loss: 0.2429 - acc: 0.8750 - val_loss: 0.2975 - val_acc: 0.8550
# Epoch 173/200
#  - 0s - loss: 0.2096 - acc: 0.8950 - val_loss: 0.2226 - val_acc: 0.9000
# Epoch 174/200
#  - 0s - loss: 0.1986 - acc: 0.9100 - val_loss: 0.2244 - val_acc: 0.8900
# Epoch 175/200
#  - 0s - loss: 0.1995 - acc: 0.9000 - val_loss: 0.2348 - val_acc: 0.8950
# Epoch 176/200
#  - 0s - loss: 0.2037 - acc: 0.9100 - val_loss: 0.2655 - val_acc: 0.8650
# Epoch 177/200
#  - 0s - loss: 0.2084 - acc: 0.9050 - val_loss: 0.2205 - val_acc: 0.8950
# Epoch 178/200
#  - 0s - loss: 0.2023 - acc: 0.9000 - val_loss: 0.2243 - val_acc: 0.9000
# Epoch 179/200
#  - 0s - loss: 0.1994 - acc: 0.9100 - val_loss: 0.2552 - val_acc: 0.8750
# Epoch 180/200
#  - 0s - loss: 0.2110 - acc: 0.9200 - val_loss: 0.2178 - val_acc: 0.8900
# Epoch 181/200
#  - 0s - loss: 0.2030 - acc: 0.9000 - val_loss: 0.2260 - val_acc: 0.9000
# Epoch 182/200
#  - 0s - loss: 0.1992 - acc: 0.9050 - val_loss: 0.2233 - val_acc: 0.8950
# Epoch 183/200
#  - 0s - loss: 0.2064 - acc: 0.9000 - val_loss: 0.2359 - val_acc: 0.8950
# Epoch 184/200
#  - 0s - loss: 0.2003 - acc: 0.9000 - val_loss: 0.2535 - val_acc: 0.8850
# Epoch 185/200
#  - 0s - loss: 0.2014 - acc: 0.9050 - val_loss: 0.2197 - val_acc: 0.8950
# Epoch 186/200
#  - 0s - loss: 0.2067 - acc: 0.9050 - val_loss: 0.2468 - val_acc: 0.8850
# Epoch 187/200
#  - 0s - loss: 0.2027 - acc: 0.9100 - val_loss: 0.2270 - val_acc: 0.9000
# Epoch 188/200
#  - 0s - loss: 0.2018 - acc: 0.9050 - val_loss: 0.2551 - val_acc: 0.8850
# Epoch 189/200
#  - 0s - loss: 0.2029 - acc: 0.9000 - val_loss: 0.2299 - val_acc: 0.9000
# Epoch 190/200
#  - 0s - loss: 0.2027 - acc: 0.9000 - val_loss: 0.2228 - val_acc: 0.8950
# Epoch 191/200
#  - 0s - loss: 0.2839 - acc: 0.8750 - val_loss: 0.4472 - val_acc: 0.8550
# Epoch 192/200
#  - 0s - loss: 0.2116 - acc: 0.8950 - val_loss: 0.2240 - val_acc: 0.9000
# Epoch 193/200
#  - 0s - loss: 0.1991 - acc: 0.9050 - val_loss: 0.2538 - val_acc: 0.8850
# Epoch 194/200
#  - 0s - loss: 0.2074 - acc: 0.9000 - val_loss: 0.2198 - val_acc: 0.9000
# Epoch 195/200
#  - 0s - loss: 0.1983 - acc: 0.9100 - val_loss: 0.2346 - val_acc: 0.8650
# Epoch 196/200
#  - 0s - loss: 0.2017 - acc: 0.9050 - val_loss: 0.2284 - val_acc: 0.8800
# Epoch 197/200
#  - 0s - loss: 0.2047 - acc: 0.9000 - val_loss: 0.2222 - val_acc: 0.8950
# Epoch 198/200
#  - 0s - loss: 0.2003 - acc: 0.9000 - val_loss: 0.2177 - val_acc: 0.9000
# Epoch 199/200
#  - 0s - loss: 0.1988 - acc: 0.9100 - val_loss: 0.2370 - val_acc: 0.8950
# Epoch 200/200
#  - 0s - loss: 0.2083 - acc: 0.9000 - val_loss: 0.2244 - val_acc: 0.9000
